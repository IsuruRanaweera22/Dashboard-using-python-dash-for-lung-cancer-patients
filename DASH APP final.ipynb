# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
import pandas as pd
import numpy as np
from dash.dependencies import Input, Output
import plotly.express as px
import plotly.graph_objects as go
# Out:
# <ipython-input-2-ed42ccde6f34>:2: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
# <ipython-input-2-ed42ccde6f34>:3: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html

# %%
app = dash.Dash()

# %%
data = pd.read_csv('survey lung cancer.csv')
data_Yes = pd.DataFrame(data [(data["LUNG_CANCER"]== "YES")]).reset_index()
data_No = pd.DataFrame(data [(data["LUNG_CANCER"]== "NO")]).reset_index()

# %%
data_Yes
# Out:
#      index GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        0      M   69        1               2        2              1
# 1        1      M   74        2               1        1              1
# 2        5      F   75        1               2        1              1
# 3        6      M   52        2               1        1              1
# 4        7      F   51        2               2        2              2
# ..     ...    ...  ...      ...             ...      ...            ...
# 265    304      F   56        1               1        1              2
# 266    305      M   70        2               1        1              1
# 267    306      M   58        2               1        1              1
# 268    307      M   67        2               1        2              1
# 269    308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# ...

# %%
data.head()
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   69        1               2        2              1
# 1      M   74        2               1        1              1
# 2      F   59        1               1        1              2
# 3      M   63        2               2        2              1
# 4      F   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# ...

# %%
sheet0 = {'color':'black','display':'flex','flex-direction':'column','text-align':'center','width':'50%','padding':'10px','background':'#000000', 'border-radius':'10px','margin':'10px'}

sheet1 = {'fontSize':18,'font-weight':'bold','color':'black','display':'flex','flex-direction':'column','text-align':'center','width':'50%','padding':'10px','background':'#2e0101', 'border-radius':'10px','margin':'10px'}

sheet11 = {'fontSize':18,'font-weight':'bold','color':'black','display':'flex','flex-direction':'column','text-align':'center','width':'50%','padding':'10px','background':'#0d0f26', 'border-radius':'10px','margin':'10px'}

sheet2 = {'color':'black','display':'flex','flex-direction':'column','text-align':'center','width':'25%','padding':'10px','background':'#fff5ba', 'border-radius':'10px','margin':'10px'}

sheet3 = {'color':'black','display':'flex','flex-direction':'column','text-align':'center','width':'21.25%','padding':'10px','background':'#fff5ba', 'border-radius':'10px','margin':'10px'}

sheet4 = {'border': '2px solid #ffffff','color':'#262323','display':'flex','flex-direction':'column','text-align':'center','width':'33.3%','padding':'10px','background':'linear-gradient(to top, #111112 0%, #12129e 100%)', 'border-radius':'10px','margin':'10px'}

fig_L = {
            'plot_bgcolor': '#454949',
            'paper_bgcolor': '#454949',
            #'title': 'Lung Cancer Patient',
            'xaxis':{'title':'Lung Cancer'},
            'yaxis':{'title':'Number of patients'},
            'font': {'color': '#ffff80','size':10},
            'legend':{'font':{'size':9}}
         }

# %%
data = pd.read_csv('survey lung cancer.csv')

# %%
Lung_cancer_status = data["LUNG_CANCER"].value_counts()
Gender = data["GENDER"].value_counts()
data["AGE"].value_counts()
# Out:
# 64    20
# 56    19
# 63    19
# 62    18
# 60    17
# 61    16
# 59    15
# 70    15
# 67    13
# 58    13
# 69    11
# 55    11
# 71    10
# 72    10
# 57     9
# 77     9
# 68     9
# 54     8
# 51     8
# 65     7
# 74     6
# 75     5
# 73     4
# 47     4
# 76     4
# 66     4
# 53     4
# 52     4
# 49     3
# 81     2
# 44     2
# 48     2
# 78     2
# 79     1
# 21     1
# 38     1
# 46     1
# 39     1
# 87     1
# Name: AGE, dtype: int64

# %%
dt1 = data [(data["LUNG_CANCER"]== "YES") & (data["WHEEZING"]== 2) ]["WHEEZING"].count()
dt2 = data [(data["LUNG_CANCER"]== "YES") & (data["WHEEZING"]== 1) ]["WHEEZING"].count()
dt3 = data [(data["LUNG_CANCER"]== "NO") & (data["WHEEZING"]== 2) ]["WHEEZING"].count()
dt4 = data [(data["LUNG_CANCER"]== "NO") & (data["WHEEZING"]== 1) ]["WHEEZING"].count()

# %%
dt5 = data [(data["LUNG_CANCER"]== "YES") & (data["COUGHING"]== 2) ]["COUGHING"].count()
dt6 = data [(data["LUNG_CANCER"]== "YES") & (data["COUGHING"]== 1) ]["COUGHING"].count()
dt7 = data [(data["LUNG_CANCER"]== "NO") & (data["COUGHING"]== 2) ]["COUGHING"].count()
dt8 = data [(data["LUNG_CANCER"]== "NO") & (data["COUGHING"]== 1) ]["COUGHING"].count()

# %%
dt9 = data_Yes[(data_Yes["LUNG_CANCER"]== "YES") & (data_Yes["FATIGUE "]== 2) ]["FATIGUE "].count()
dt10 = data_Yes[(data_Yes["LUNG_CANCER"]== "YES") & (data_Yes["FATIGUE "]== 1) ]["FATIGUE "].count()
dt11 = data_No[(data_No["LUNG_CANCER"]== "NO") & (data_No["FATIGUE "]== 2) ]["FATIGUE "].count()
dt12 = data_No[(data_No["LUNG_CANCER"]== "NO") & (data_No["FATIGUE "]== 1) ]["FATIGUE "].count()

# %%
colors = {
    'background': '#262323',
    'background1': '#3f2e2e',
    'background2':'#222338',
    'indicators':'linear-gradient(to top, #111112 0%, #12129e 100%)',
    'text': '#ffff80'
}

app.layout = html.Div([
    

    #title
    html.Div([
        html.H1("LUNG CANCER STATISTICS DASHBOARD")
    ],style={'text-align':'center','font-family':'Teko','font-size':20,'color':'white','border': '2px solid #ffffff',
                    'padding':'5px','border-radius':'10px','margin':'5px' ,'background':'linear-gradient(to bottom, #000099 0%, #110022 100%)'}),

    html.Div([

        html.Div([
            html.Div([
                html.H3("Total Respondents",style={'color': colors['text']}),
                html.H1(len(data),style={'color': colors['text']})
            ],style=sheet4),
            html.Div([
                html.H3("Total Patients",style={'color': colors['text']}),
                html.H1(len(data_Yes),style={'color': colors['text']})
            ],style=sheet4),
            html.Div([
                html.H3("Total Non-Patients",style={'color': colors['text']}),
                html.H1(len(data_No),style={'color': colors['text']})
            ],style=sheet4),
        ],style= {'display':'flex','flex-direction':'row','text-align':'center','color':'#4d5063','padding':'5px','background':'#1E1C1C', 
            'border-radius':'10px','margin':'5px','width':'98%'}), 
 
    ]),

    
    html.Div([
        #left
        html.Div([
            #lung cancer patients
            html.Div([
                dcc.Graph(
                id='graph1',
                figure={
                        'data': [{'labels': ['Yes', 'No'], 'values': [Lung_cancer_status[0],Lung_cancer_status[1]],
                                  'type': 'pie', 'name': 'patientData'}],
                              'layout': {
                                    'plot_bgcolor': colors['background'],
                                    'paper_bgcolor': colors['background'],
                                    'title': 'Lung Cancer Patient',
                                    'font': {
                                    'color': colors['text']
                                     }
                                }
                        })
                
                
            ]),
            #gender distribution_pie
            html.Div([
                dcc.Graph(
                id='graph2',
                figure={
                        'data': [{'labels': ['Male', 'Female'], 'values': [Gender[0],Gender[1]],
                                  'type': 'pie', 'name': 'patientData'}],
                    
                               'layout': {
                                    'plot_bgcolor': colors['background'],
                                    'paper_bgcolor': colors['background'],
                                    'title': 'Gender Distribution',
                                    'font': {
                                    'color': colors['text']
                                     }
                                }
                    
                        })
            ]),
            #gender distribution_hist
            html.Div([
                dcc.Graph(id='graph3', style={'height':350},
                      figure={    
                      'layout':{
                      'plot_bgcolor': colors['background'],
                      'paper_bgcolor': colors['background'],
                      'title': 'Gender Distribution',
                      'font': {'color': colors['text']}
                              }
                      }),
             
            html.Label("Please select the range :", style={'color':'#ffff80'}),
                dcc.RangeSlider(
                    id='range1',
                    min = 0,
                    max = 85,
                    value = [0,5],
                    marks = {i : i for i in range(0,85,5)},
                    step = 1,
                ),
            ]),
        
        ],style={'border': '2px solid #ffffff','display':'flex','flex-direction':'column','text-align':'center','text-align':'center','color':'#4d5063','padding':'5px','background':colors['background'], 
                 'border-radius':'10px','margin':'5px','width':'24%', 'height':'1340px'}),
        
        #right
        html.Div([
##########################################################################            
            
            #Uni-Variate Analysis
            html.Div([
            html.H2("Uni-Variate Analysis",style={'color': colors['text'],'margin':'40px'}),
            ],style={'border': '2px solid #ffffff','border-radius':'10px','margin':'5px'}),
            
            html.Div([
                
                #age distribution with patient's status
                html.Div([
                    
                    html.Div([
                        html.H2("Age distribution with patient's status",style={'color': colors['text']}),
                        html.Label('Lung Cancer Patient',style={'color': colors['text']}),
                        dcc.Checklist(
                            id = "my_checklist",
                            options=[
                                {'label': 'Yes', 'value': 'YES'},
                                {'label': 'No', 'value': 'NO'}
                            ],
                            value=['Yes', 'NO'],
                            style={'color':'white'}
                        ),
                        ],style={'text-align':'center','fontSize':20,'font-weight':'bold','color':'white','background':colors['background'],'border-radius':'3px','margin':'4px','padding':'5px','width':'98%'}),
                    
                    dcc.Graph(id='graph4', style={'height':'70vh'},
                              figure={
                                  'layout':{
                                      'plot_bgcolor': colors['background'],
                                      'paper_bgcolor': colors['background'],
                                      'font': {'color': colors['text']}
                                  }
                              }),
                    
                    
                ],style=sheet0),
                #Gender_Lung Cancer Patient_pie
                html.Div([
                    
                    html.Div([
                        html.H2('Gender',style={'color': colors['text']}),
                        html.Label('Lung Cancer Patient',style={'color': colors['text']}),
                        dcc.RadioItems(
                            id='cancer',
                            options=[{'label':'Yes', 'value':'YES'},
                                     {'label':'No', 'value':'NO'}
                                    ],
                            value='YES',
                            style={'color':'white'}
                        ),
                        ],style={'fontSize':20,'font-weight':'bold','color':'white','background':colors['background'],'border-radius':'3px','margin':'4px','padding':'5px','width':'98%'}),
                   
                    dcc.Graph(id='pie2',style={'height':'70vh'},
                              figure={
                                  'layout':{
                                      'plot_bgcolor': colors['background'],
                                      'paper_bgcolor': colors['background'],
                                      'font': {'color': colors['text']}
                                  }
                              }
                             )

                ],style=sheet0),
                
                
                
                
        ],style={'border': '2px solid #ffffff','display':'flex','flex-direction':'row','text-align':'center','color':'#4d5063','padding':'5px','background':colors['background'], 
            'border-radius':'10px','margin':'5px','width':'98%'}),     
###############################################################################################################################           
        html.Center(
        html.Div([
            
            
            
            
            
             ##### Indicators ######
            html.Div([
            html.Div([    
            html.H3('Lung Cancer Status',style={'text-align':'center','color':'yellow','font-size':'25'}),
            ],style={'padding':'2px','margin':'3px','background':colors['indicators'],'color':'white','text-align':'center','width':'99%','border-radius':'10px'}),
            
            html.Div([
                html.Div([
                html.P('YES',style={'font-weight':'bold','text-align':'center','color':'red','font-size':'25'}),
                ],style={'display':'flex','flex-direction':'column','padding':'2px','margin':'3px','background':colors['indicators'],'text-align':'center','width':'50%','border-radius':'10px'}),

                html.Div([
                html.P('NO',style={'font-weight':'bold','text-align':'center','color':'#00ff00','font-size':'25'}),
                ],style={'display':'flex','flex-direction':'column','padding':'2px','margin':'3px','background':colors['indicators'],'text-align':'center','width':'50%','border-radius':'10px'}),
            ],style={'display':'flex','flex-direction':'row'}),
            
            html.Div([
              html.Div([
                html.Div([
                        html.Div([
                        html.Center(
                        html.Img(src="/assets/female.png",alt="Female",width="20%",height="20%")),
                        html.P('Female: 46%'),
                        ##
                        ],style={'padding':'2px','margin':'2px','background':colors['indicators'],'color':'white','text-align':'center','width':'49%','border-radius':'10px'}),

                        html.Div([
                        html.Center(
                        html.Img(src="/assets/male.png",alt="Female",width="20%",height="20%")),
                        html.P('Male: 54%'),
                        ##
                        ],style={'padding':'2px','margin':'2px','background':colors['indicators'],'color':'white','text-align':'center','width':'49%','border-radius':'10px'})
                ],style={'margin':'3px','color':'white','display':'flex','flex-direction':'row','text-align':'center'}),
              ],style={'margin':'2px','border': '1px solid #ff0000','display':'flex','flex-direction':'row','border-radius':'10px'}), 
              html.Div([  
                html.Div([
                        html.Div([
                        html.Center(
                        html.Img(src="/assets/female.png",alt="Female",width="20%",height="20%")),
                        html.P('Female: 44%'),
                        ##
                        ],style={'padding':'2px','margin':'2px','background':colors['indicators'],'color':'white','text-align':'center','width':'49%','border-radius':'10px'}),

                        html.Div([
                        html.Center(
                        html.Img(src="/assets/male.png",alt="Female",width="20%",height="20%")),
                        html.P('Male: 56%'),
                        ##
                        ],style={'padding':'2px','margin':'2px','background':colors['indicators'],'color':'white','text-align':'center','width':'49%','border-radius':'10px'})
                ],style={'margin':'3px','color':'white','display':'flex','flex-direction':'row','text-align':'center'}),
              ],style={'margin':'2px','border': '1px solid #00ff00','display':'flex','flex-direction':'row','border-radius':'10px'}),                
            ],style={'display':'flex','flex-direction':'row'}),    
                
            
            
            ],style={'border': '1px solid #ffffff','width':'65%','color':'white','background-color':'#000000','margin':'3px','padding':'5px','border-radius':'10px'}),
               #####  INDICATORS #####          
            
            html.Div([
            html.Br(),
            html.Br(),
            html.H2('Avg. Age People Diagnosed',style={'font-family':'Lucida Bright','fontSize':'70','font-weight': '100'}),
            html.H2('with Lung Cancer',style={'font-family':'Lucida Bright','fontSize':'70','font-weight': '100'}),
            html.H2('62 Years',style={'font-weight':'bold','text-align':'center','color':'red','font-size':'35','font-weight': '200'})
                
                
            ],style={'border': '1px solid #ffffff','width':'33%','color':'yellow','background':colors['indicators'],'margin':'3px','padding':'5px','border-radius':'10px'}),           
            
               #######################
            
            
                ],style={'display':'flex','flex-direction':'row','background':'black','height':'310px','margin':'5px','border-radius':'10px'}) ), 

        ],style={'display':'flex','flex-direction':'column','text-align':'center','color':'#4d5063','padding':'5px','background':'black', 
                                        'border-radius':'10px','margin':'5px','width':'75%'}),
    ],style = {'border-radius':'10px','display':'flex', 'flex-direction':'row','background':'#000000'}),
############################################################################################################################         

    
    html.Div([
        
            html.Div([  
            html.H2("Lung Cancer Patient",style={'fontSize':35,'text-align':'center','color':'#ffffff'} )     
            ],style={'border': '2px solid #ffffff','border-radius':'10px','padding':'5px','margin':'5px','width':'98%','background':'linear-gradient(to top, #111125 0%, #12125b 100%)'}), 
        
            html.Div([
########################################################...........YES..........#################################################
                dcc.Tabs([
                    dcc.Tab(label='YES', children=[
                        
                        #habits
                        html.Div([
                            
                        html.H2("Habits",style={'color': colors['text']})
                        ],style={'text-align':'center','font-family':'Teko','font-size':15,
                                 'padding':'5px', 'border-radius':'10px','width':'98%','margin':'5px','background':colors['background1']}),
                        
                        html.Div([
                            #combo_boxes
                            html.Div([
                                
                                #select_factor
                                html.Div([
                                    html.P("Select Factor:"),
                                    dcc.Dropdown(
                                        id='factor',
                                        value='SMOKING',
                                        options=[{'value': x, 'label': x}
                                                 for x in ['SMOKING','ALCOHOL_CONSUMING']],
                                        clearable=False,
                                        style={'color':'black'}
                                    ),
                                ],style={'fontSize':20,'font-weight':'bold','color':'white','background':colors['background1'],'border-radius':'25px','margin':'30px','padding':'30px'}),
                            
                            ], style =  {'color':'black','display':'flex','flex-direction':'column','text-align':'center','width':'50%','height':'50%','padding':'10px','background':'#2e0101', 'border-radius':'25px','margin':'20px'}),
                            
                            
                            #smoking_donut
                            html.Div([
                                dcc.Graph(id="donut1",
                                          figure={
                                              'layout':{
                                                  'plot_bgcolor': colors['background'],
                                                  'paper_bgcolor': colors['background'],
                                                  'font': {'color': colors['text']}
                                              }
                                          }
                                         )
                            
                            ], style = sheet1),
                        
                        ], style={'display':'flex', 'flex-direction':'row','width':'98%','text-align':'center','font-family':'Teko','font-size':15,
                                  'padding':'5px','background':'#ffffff', 'border-radius':'10px','margin':'5px','background':colors['background1']}),
                        
###############################################################################################################################                        
                        
                        #special symptoms
                        html.Div([
                            
                        html.H2("Symptoms",style={'color': colors['text']})
                        ],style={'text-align':'center','font-family':'Teko','font-size':15,
                                 'padding':'5px', 'border-radius':'10px','width':'98%','margin':'5px','background':colors['background1']}),
                        
                        html.Div([
                                
                            #select_factor
                            html.Div([
                                    html.H3("Select Factor:",style={'color':'white'}),
                                    dcc.Dropdown(
                                        id='fac1',
                                        value = 'YELLOW_FINGERS',
                                        options=[{'value': x, 'label': x}
                                                 for x in ['YELLOW_FINGERS','SWALLOWING_DIFFICULTY','CHEST_PAIN','SHORTNESS_OF_BREATH']],
                                        clearable=False,
                                        style={'color':'black'}
                                    ),

                                dcc.Graph(id="donut2",
                                          figure={
                                              'layout':{
                                                  'plot_bgcolor': colors['background1'],
                                                  'paper_bgcolor': colors['background1'],
                                                  'font': {'color': colors['text']}
                                              }
                                          }
                                         
                                         )
                            
                            ], style = sheet1),
                            
                            #select_factor
                            html.Div([
                                    html.H3("Select Factor:",style={'color':'white'}),
                                    dcc.Dropdown(
                                        id='fac2',
                                        value = 'WHEEZING',
                                        options=[{'value': x, 'label': x}
                                                 for x in ['WHEEZING','COUGHING','FATIGUE ']],
                                        clearable=False,
                                        style={'color':'black'}
                                    ),

                                dcc.Graph(id="barplot1",
                                          figure={
                                              'layout':{
                                                  'plot_bgcolor': colors['background'],
                                                  'paper_bgcolor': colors['background'],
                                                  'font': {'color': colors['text']}
                                              }
                                          }
                                         
                                         )
                            
                            ], style = sheet1),
                        
                        ], style={'display':'flex', 'flex-direction':'row','width':'98%','text-align':'center','font-family':'Teko','font-size':15,
            'padding':'5px', 'border-radius':'10px','margin':'5px','background':colors['background1']}),
                        
                        
                        #External Factors
                        html.Div([
                            html.H2("External Factors",style={'color': colors['text'],'background':colors['background1']})
                        ],style={'text-align':'center','font-family':'Teko','font-size':15,
                                 'padding':'5px','background':'#ffffff', 'border-radius':'10px','width':'98%','margin':'5px','background':colors['background1']}),
                        
                        html.Div([
                            #combo_boxes
                            html.Div([
                                
                                #select_factor
                                html.Div([
                                    html.P("Select Factor:"),
                                    dcc.Dropdown(
                                        id='fact3',
                                        value='CHRONIC_DISEASE',
                                        options=[{'value': x, 'label': x}
                                                 for x in ['CHRONIC_DISEASE','ANXIETY','PEER_PRESSURE','ALLERGY ']],
                                        clearable=False,
                                        style={'color':'black'}
                                    ),
                                ],style={'fontSize':20,'font-weight':'bold','color':'white','background':'#2e0101','border-radius':'25px','margin':'30px','padding':'30px'}),
                                
                                #select graph
                                html.Div([
                                    html.P("Select Graph Type:"),
                                    dcc.Dropdown(
                                        id='graph_type',
                                        value='Bar Chart',
                                        options=[{'value': x, 'label': x}
                                                 for x in ['Bar Chart', 'Pie Chart']],
                                        clearable=False,
                        style={'color':'black'}
                                    ),
                                ],style={'fontSize':20,'font-weight':'bold','color':'white','background':'#2e0101','border-radius':'25px','margin':'30px','padding':'30px'})
                            
                            ], style =  {'color':'black','display':'flex','flex-direction':'column','text-align':'center','width':'50%','padding':'10px','background':colors['background1'], 'border-radius':'25px','margin':'20px'}),
                            
                            #external factor plot
                            html.Div([
                                dcc.Graph(id="barplot2",
                                          figure={
                                              'layout':{
                                                  'plot_bgcolor': colors['background1'],
                                                  'paper_bgcolor': colors['background1'],
                                                  'font': {'color': colors['text']}
                                              }
                                          }
                                         
                                         )
                            
                            ], style = sheet1),
                        
                        ], style={'display':'flex', 'flex-direction':'row','width':'98%','text-align':'center','font-family':'Teko','font-size':15,
                                  'padding':'5px','background':'#ffffff', 'border-radius':'10px','margin':'5px','background':colors['background1']}),
                        
                        
                    ],style= {  'background-color':'red',
                                'borderBottom': '2px solid #d6d6d6',
                                'margin': '5px',
                                'color':'white',
                                'fontWeight': 'bold',
                                'border-radius':'2px'
                            },
                           
                      selected_style = {
                                'borderTop': '5px solid gold',
                                'borderBottom': '2px solid #ffffff',
                                'backgroundColor':'maroon',
                                'color': 'white',
                                'margin': '5px',
                                'fontWeight': 'bold',
                                'border-radius':'2px'
                            } ),
############################################............YES END...........######################################################
                    
                    dcc.Tab(label='NO', children=[
                        
############################################............NO...........######################################################                        
                        
                        #habits
                        html.Div([
                            
                            html.H2("Habits",style={'color': colors['text']})
                        ],style={'text-align':'center','font-family':'Teko','font-size':15,
                                 'padding':'5px','background':'#ffffff', 'border-radius':'10px','width':'98%','margin':'5px','background':colors['background2']}),
                        
                        html.Div([
                            #combo_boxes
                            html.Div([
                                
                                #select_factor
                                html.Div([
                                    html.P("Select Factor:"),
                                    dcc.Dropdown(
                                        id='factor_no',
                                        value='SMOKING',
                                        options=[{'value': x, 'label': x}
                                                 for x in ['SMOKING','ALCOHOL_CONSUMING']],
                                        clearable=False,
                                        style={'color':'black'}
                                    ),
                                ],style={'fontSize':20,'font-weight':'bold','color':'white','background':colors['background2'],'border-radius':'25px','margin':'30px','padding':'30px'}),
                            
                            ], style =  {'color':'black','display':'flex','flex-direction':'column','text-align':'center','width':'50%','height':'50%','padding':'10px','background':'#0d0f26', 'border-radius':'25px','margin':'20px'}),
                            
                            
                            #smoking_donut
                            html.Div([
                                dcc.Graph(id="donut1_no",
                                          figure={
                                              'layout':{
                                                  'plot_bgcolor': colors['background2'],
                                                  'paper_bgcolor': colors['background2'],
                                                  'font': {'color': colors['text']}
                                              }
                                          }
                                         )
                            
                            ], style = sheet11),
                        
                        ], style={'display':'flex', 'flex-direction':'row','width':'98%','text-align':'center','font-family':'Teko','font-size':15,
                                  'padding':'5px','background':'#ffffff', 'border-radius':'10px','margin':'5px','background':colors['background2']}),
###############################################################################################################################                        
                        
                        #special symptoms
                        html.Div([
                            
                            html.H2("Symptoms",style={'color': colors['text']})
                        ],style={'text-align':'center','font-family':'Teko','font-size':15,
                                 'padding':'5px','background':'#ffffff', 'border-radius':'10px','width':'98%','margin':'5px','background':colors['background2']}),
                        
                        html.Div([
                                
                            #select_factor
                            html.Div([
                                    html.H3("Select Factor:",style={'color':'white'}),
                                    dcc.Dropdown(
                                        id='fac1_no',
                                        value = 'YELLOW_FINGERS',
                                        options=[{'value': x, 'label': x}
                                                 for x in ['YELLOW_FINGERS','SWALLOWING_DIFFICULTY','CHEST_PAIN','SHORTNESS_OF_BREATH']],
                                        clearable=False,
                                        style={'color':'black'}
                                    ),

                                dcc.Graph(id="donut2_no",
                                          figure={
                                              'layout':{
                                                  'plot_bgcolor': colors['background2'],
                                                  'paper_bgcolor': colors['background2'],
                                                  'font': {'color': colors['text']}
                                              }
                                          }
                                         
                                         )
                            
                            ], style = sheet11),
                            
                            #select_factor
                            html.Div([
                                    html.H3("Select Factor:",style={'color':'white'}),
                                    dcc.Dropdown(
                                        id='fac2_no',
                                        value = 'WHEEZING',
                                        options=[{'value': x, 'label': x}
                                                 for x in ['WHEEZING','COUGHING','FATIGUE ']],
                                        clearable=False,
                                        style={'color':'black'}
                                    ),

                                dcc.Graph(id="barplot1_no",
                                          figure={
                                              'layout':{
                                                  'plot_bgcolor': colors['background2'],
                                                  'paper_bgcolor': colors['background2'],
                                                  'font': {'color': colors['text']}
                                              }
                                          }
                                         
                                         )
                            
                            ], style = sheet11),
                        
                        ], style={'display':'flex', 'flex-direction':'row','width':'98%','text-align':'center','font-family':'Teko','font-size':15,
            'padding':'5px','background':'#ffffff', 'border-radius':'10px','margin':'5px','background':colors['background2']}),
                        
                       
                        #External Factors
                        html.Div([
                            html.H2("External Factors",style={'color': colors['text']})
                        ],style={'text-align':'center','font-family':'Teko','font-size':15,
                                 'padding':'5px','background':'#ffffff', 'border-radius':'10px','width':'98%','margin':'5px','background':colors['background2']}),
                        
                        html.Div([
                            #combo_boxes
                            html.Div([
                                
                                #select_factor
                                html.Div([
                                    html.P("Select Factor:"),
                                    dcc.Dropdown(
                                        id='fact3_no',
                                        value='CHRONIC_DISEASE',
                                        options=[{'value': x, 'label': x}
                                                 for x in ['CHRONIC_DISEASE','ANXIETY','PEER_PRESSURE','ALLERGY ']],
                                        clearable=False,
                                        style={'color':'black'}
                                    ),
                                ],style={'fontSize':20,'font-weight':'bold','color':'white','background':'#0d0f26','border-radius':'25px','margin':'30px','padding':'30px'}),
                                
                                #select graph
                                html.Div([
                                    html.P("Select Graph Type:"),
                                    dcc.Dropdown(
                                        id='graph_type_no',
                                        value='Bar Chart',
                                        options=[{'value': x, 'label': x}
                                                 for x in ['Bar Chart', 'Pie Chart']],
                                        clearable=False,
                        style={'color':'black'}
                                    ),
                                ],style={'fontSize':20,'font-weight':'bold','color':'white','background':'#0d0f26','border-radius':'25px','margin':'30px','padding':'30px'})
                            
                            ], style =  {'color':'black','display':'flex','flex-direction':'column','text-align':'center','width':'50%','padding':'10px','background':colors['background2'], 'border-radius':'25px','margin':'20px'}),
                            
                            #external factor plot
                            html.Div([
                                dcc.Graph(id="barplot2_no",
                                          figure={
                                              'layout':{
                                                  'plot_bgcolor': colors['background2'],
                                                  'paper_bgcolor': colors['background2'],
                                                  'font': {'color': colors['text']}
                                              }
                                          }
                                         
                                         )
                            
                            ], style = sheet11),
                        
                        ], style={'display':'flex', 'flex-direction':'row','width':'98%','text-align':'center','font-family':'Teko','font-size':15,
                                  'padding':'5px','background':'#ffffff', 'border-radius':'10px','margin':'5px','background':colors['background2']}),
                        
                        
                    ],style= {  'background-color':'blue',
                                'borderBottom': '2px solid #d6d6d6',
                                'margin': '5px',
                                'color':'white',
                                'fontWeight': 'bold',
                                'border-radius':'2px'
                            },
                           
                      selected_style = {
                                'borderTop': '5px solid gold',
                                'borderBottom': '2px solid #ffffff',
                                'backgroundColor':'#05305c',
                                'color': 'white',
                                'margin': '5px',
                                'fontWeight': 'bold',
                                'border-radius':'2px'
                            }),
############################################............NO END...........######################################################            
                ],style={'color':'#6677dd','background-color':'#000000','width':'98%','margin':'5px','border-radius':'10px','padding':'5px'})
                
                
                
    ],style={'background-color':'#000000','margin':'5px','border-radius':'10px','padding':'5px','align':'justify'})
            
          

    ]),
    


],style = {'border-radius':'10px','padding':'5px','margin':'5px','display':'flex', 'flex-direction':'column','background':'black', 'width':'100%'})

# %%
@app.callback(
    Output('graph3', 'figure'),
    [Input('range1', 'value')])

def generate_graph1(ranger):
    
    dt = data[(data['AGE']>=ranger[0]) & (data['AGE']<=ranger[1])]
    fig = px.histogram(dt,x = "AGE", nbins = 10, title="Age Distribution")
    fig.update_layout({'plot_bgcolor':colors['background'],
                       'paper_bgcolor': colors['background'],
                       'font': {'color': colors['text']}
                      })

    return fig

# %%
@app.callback(
    Output("graph4", "figure"), 
    [Input("my_checklist","value")])

def update_graph(options_chosen):
    
    dff = data[data["LUNG_CANCER"].isin(options_chosen)]
    print(dff["LUNG_CANCER"].unique())
    
    fig = px.box(dff,x="LUNG_CANCER", y="AGE")
    
    fig.update_layout({'plot_bgcolor':colors['background'],
                'paper_bgcolor': colors['background'],
                 'font': {'color': colors['text']}
                })    
    
    return fig

# %%
@app.callback(
    Output('pie2','figure'),
    Input('cancer', 'value')
)
def generate_graph(cancer):
    
    if(cancer=='YES' or cancer=='NO'):
            dt=data[data['LUNG_CANCER']==cancer]['GENDER'].value_counts()
            fig = px.pie(values=dt,names=["Male", "Female"])
            fig.update_layout({'plot_bgcolor':colors['background'],
                       'paper_bgcolor': colors['background'],
                       'font': {'color': colors['text']}
                      })

    return fig

# %%
@app.callback(
    Output("donut1", "figure"), 
    [Input("factor", "value")])

def generate_chart(factor):
    
    if(factor=='SMOKING'):
        dt=data_Yes['SMOKING'].value_counts()
        fig = go.Figure(data=[go.Pie(values=dt, labels=['Yes','No'],hole=.3)])
        fig.update_layout(
            title_text="Smoking")        
        
    if(factor=='ALCOHOL_CONSUMING'):
        dt=data_Yes['ALCOHOL_CONSUMING'].value_counts()
        fig = go.Figure(data=[go.Pie(values=dt, labels=['Yes','No'],hole=.3)])
        fig.update_layout(
            title_text="ALCOHOL_CONSUMING")

    fig.update_layout({'plot_bgcolor':colors['background1'],
                'paper_bgcolor': colors['background1'],
                 'font': {'color': colors['text']}
                })    
    
    return fig

# %%
########################
@app.callback(
    Output("donut1_no", "figure"), 
    [Input("factor_no", "value")])

def generate_chart(factor):
    
    if(factor=='SMOKING'):
        dt=data_No['SMOKING'].value_counts()
        fig = go.Figure(data=[go.Pie(values=dt, labels=['Yes','No'],hole=.3)])
        fig.update_layout(
            title_text="Smoking")        
        
    if(factor=='ALCOHOL_CONSUMING'):
        dt=data_No['ALCOHOL_CONSUMING'].value_counts()
        fig = go.Figure(data=[go.Pie(values=dt, labels=['Yes','No'],hole=.3)])
        fig.update_layout(
            title_text="ALCOHOL_CONSUMING")

    fig.update_layout({'plot_bgcolor':colors['background2'],
                'paper_bgcolor': colors['background2'],
                 'font': {'color': colors['text']}
                })    
    
    return fig

# %%
@app.callback(
    Output("donut2", "figure"), 
    [Input("fac1", "value")])

def generate_chart(fac1):
    
    if(fac1=='YELLOW_FINGERS'):
        dt=data_Yes['YELLOW_FINGERS'].value_counts()
        fig = go.Figure(data=[go.Pie(values=dt, labels=['Yes','No'],hole=.3)])
        fig.update_layout(
            title_text="Yellow Fingers")      
        
    if(fac1=='SHORTNESS_OF_BREATH'):
        dt=data_Yes['SHORTNESS_OF_BREATH'].value_counts()
        fig = go.Figure(data=[go.Pie(values=dt, labels=['Yes','No'],hole=.3)])
        fig.update_layout(
            title_text="Shortness Of Breath")
        
    if(fac1=='CHEST_PAIN'):
        dt=data_Yes['CHEST_PAIN'].value_counts()
        fig = go.Figure(data=[go.Pie(values=dt, labels=['Yes','No'],hole=.3)])
        fig.update_layout(
            title_text="Chest Pain")

    if(fac1=='SWALLOWING_DIFFICULTY'):
        dt=data_Yes['SWALLOWING_DIFFICULTY'].value_counts()
        fig = go.Figure(data=[go.Pie(values=dt, labels=['Yes','No'],hole=.3)])
        fig.update_layout(
            title_text="Swallowing Difficulty")
        
    fig.update_layout({'plot_bgcolor':colors['background1'],
                'paper_bgcolor': colors['background1'],
                 'font': {'color': colors['text']}
                })    
    
    return fig

# %%
##################################
@app.callback(
    Output("donut2_no", "figure"), 
    [Input("fac1_no", "value")])

def generate_chart(fac1):
    
    if(fac1=='YELLOW_FINGERS'):
        dt=data_No['YELLOW_FINGERS'].value_counts()
        fig = go.Figure(data=[go.Pie(values=dt, labels=['Yes','No'],hole=.3)])
        fig.update_layout(
            title_text="Yellow Fingers")      
        
    if(fac1=='SHORTNESS_OF_BREATH'):
        dt=data_No['SHORTNESS_OF_BREATH'].value_counts()
        fig = go.Figure(data=[go.Pie(values=dt, labels=['Yes','No'],hole=.3)])
        fig.update_layout(
            title_text="Shortness Of Breath")
        
    if(fac1=='CHEST_PAIN'):
        dt=data_No['CHEST_PAIN'].value_counts()
        fig = go.Figure(data=[go.Pie(values=dt, labels=['Yes','No'],hole=.3)])
        fig.update_layout(
            title_text="Chest Pain")

    if(fac1=='SWALLOWING_DIFFICULTY'):
        dt=data_No['SWALLOWING_DIFFICULTY'].value_counts()
        fig = go.Figure(data=[go.Pie(values=dt, labels=['Yes','No'],hole=.3)])
        fig.update_layout(
            title_text="Swallowing Difficulty")
        
    fig.update_layout({'plot_bgcolor':colors['background2'],
                'paper_bgcolor': colors['background2'],
                 'font': {'color': colors['text']}
                })    
    
    return fig

# %%
@app.callback(
    Output("barplot1", "figure"), 
    [Input("fac2", "value")])

def generate_chart(fac2):
    
    if(fac2=='WHEEZING'):
        dt = pd.DataFrame((((data_Yes['WHEEZING'].value_counts())/len(data_Yes))*100).round())
        dt.rename(index = {2:"Yes",1:"No"}, inplace=True)
        fig = px.bar(dt)
        fig.update_layout(
            title_text="WHEEZING")      
        
    if(fac2=='COUGHING'):
        dt = pd.DataFrame((((data_Yes['COUGHING'].value_counts())/len(data_Yes))*100).round())
        dt.rename(index = {2:"Yes",1:"No"}, inplace=True)
        fig = px.bar(dt)
        fig.update_layout(
            title_text="COUGHING")
        
    if(fac2=='FATIGUE '):
        dt = pd.DataFrame((((data_Yes['FATIGUE '].value_counts())/len(data_Yes))*100).round())
        dt.rename(index = {2:"Yes",1:"No"}, inplace=True)
        fig = px.bar(dt)
        fig.update_layout(
            title_text="FATIGUE")
        
    fig.update_layout({'plot_bgcolor':colors['background1'],
                'yaxis_title':"Percent",
                'paper_bgcolor': colors['background1'],
                 'font': {'color': colors['text']}
                })    
    
    return fig

# %%
########################
@app.callback(
    Output("barplot1_no", "figure"), 
    [Input("fac2_no", "value")])

def generate_chart(fac2):
    
    if(fac2=='WHEEZING'):
        dt = pd.DataFrame((((data_No['WHEEZING'].value_counts())/len(data_No))*100).round())
        dt.rename(index = {2:"Yes",1:"No"}, inplace=True)
        fig = px.bar(dt)
        fig.update_layout(
            title_text="WHEEZING")      
        
    if(fac2=='COUGHING'):
        dt = pd.DataFrame((((data_No['COUGHING'].value_counts())/len(data_No))*100).round())
        dt.rename(index = {2:"Yes",1:"No"}, inplace=True)
        fig = px.bar(dt)
        fig.update_layout(
            title_text="COUGHING")
        
    if(fac2=='FATIGUE '):
        dt = pd.DataFrame((((data_No['FATIGUE '].value_counts())/len(data_No))*100).round())
        dt.rename(index = {2:"Yes",1:"No"}, inplace=True)
        fig = px.bar(dt)
        fig.update_layout(
            title_text="FATIGUE")
        
    fig.update_layout({'plot_bgcolor':colors['background2'],
                'yaxis_title':"Percent",
                'paper_bgcolor': colors['background2'],
                 'font': {'color': colors['text']}
                })    
    
    return fig

# %%
@app.callback(
    Output("barplot2", "figure"), 
    [Input("fact3", "value"),Input("graph_type","value")])

def generate_chart(fact3,graph_type):
    
    if(fact3=='CHRONIC_DISEASE' and graph_type=='Bar Chart'):
        dt = pd.DataFrame((((data_Yes['CHRONIC_DISEASE'].value_counts())/len(data_Yes))*100).round())
        dt.rename(index = {2:"Yes",1:"No"}, inplace=True)
        fig = px.bar(dt)
        fig.update_layout(
            title_text="CHRONIC DISEASE")
        
    if(fact3=='CHRONIC_DISEASE' and graph_type=='Pie Chart'):
        dt=data_Yes['CHRONIC_DISEASE'].value_counts()
        fig = go.Figure(data=[go.Pie(values=dt, labels=['Yes','No'])])
        fig.update_layout(
            title_text="CHRONIC DISEASE")        
        
    if(fact3=='ANXIETY' and graph_type=='Bar Chart'):
        dt = pd.DataFrame((((data_Yes['ANXIETY'].value_counts())/len(data_Yes))*100).round())
        dt.rename(index = {2:"Yes",1:"No"}, inplace=True)
        fig = px.bar(dt)
        fig.update_layout(
            title_text="ANXIETY")
        
    if(fact3=='ANXIETY' and graph_type=='Pie Chart'):
        dt=data_Yes['ANXIETY'].value_counts()
        fig = go.Figure(data=[go.Pie(values=dt, labels=['Yes','No'])])
        fig.update_layout(
            title_text="ANXIETY")
        
    if(fact3=='PEER_PRESSURE' and graph_type=='Bar Chart'):
        dt = pd.DataFrame((((data_Yes['PEER_PRESSURE'].value_counts())/len(data_Yes))*100).round())
        dt.rename(index = {2:"Yes",1:"No"}, inplace=True)
        fig = px.bar(dt)
        fig.update_layout(
            title_text="PEER_PRESSURE")
        
    if(fact3=='PEER_PRESSURE' and graph_type=='Pie Chart'):
        dt=data_Yes['PEER_PRESSURE'].value_counts()
        fig = go.Figure(data=[go.Pie(values=dt, labels=['Yes','No'])])
        fig.update_layout(
            title_text="PEER_PRESSURE")
        
    if(fact3=='ALLERGY ' and graph_type=='Bar Chart'):
        dt = pd.DataFrame((((data_Yes['ALLERGY '].value_counts())/len(data_Yes))*100).round())
        dt.rename(index = {2:"Yes",1:"No"}, inplace=True)
        fig = px.bar(dt)
        fig.update_layout(
            title_text="ALLERGY")
        
    if(fact3=='ALLERGY ' and graph_type=='Pie Chart'):
        dt=data_Yes['ALLERGY '].value_counts()
        fig = go.Figure(data=[go.Pie(values=dt, labels=['Yes','No'])])
        fig.update_layout(
            title_text="ALLERGY")
        
    fig.update_layout({'plot_bgcolor':colors['background1'],
                'yaxis_title':"Percent",
                'paper_bgcolor': colors['background1'],
                 'font': {'color': colors['text']}
                })
        
    return fig

# %%
#########################
@app.callback(
    Output("barplot2_no", "figure"), 
    [Input("fact3_no", "value"),Input("graph_type_no","value")])

def generate_chart(fact3,graph_type):
    
    if(fact3=='CHRONIC_DISEASE' and graph_type=='Bar Chart'):
        dt = pd.DataFrame((((data_No['CHRONIC_DISEASE'].value_counts())/len(data_No))*100).round())
        dt.rename(index = {2:"Yes",1:"No"}, inplace=True)
        fig = px.bar(dt)
        fig.update_layout(
            title_text="CHRONIC DISEASE")
        
    if(fact3=='CHRONIC_DISEASE' and graph_type=='Pie Chart'):
        dt=data_No['CHRONIC_DISEASE'].value_counts()
        fig = go.Figure(data=[go.Pie(values=dt, labels=['Yes','No'])])
        fig.update_layout(
            title_text="CHRONIC DISEASE")        
        
    if(fact3=='ANXIETY' and graph_type=='Bar Chart'):
        dt = pd.DataFrame((((data_No['ANXIETY'].value_counts())/len(data_No))*100).round())
        dt.rename(index = {2:"Yes",1:"No"}, inplace=True)
        fig = px.bar(dt)
        fig.update_layout(
            title_text="ANXIETY")
        
    if(fact3=='ANXIETY' and graph_type=='Pie Chart'):
        dt=data_No['ANXIETY'].value_counts()
        fig = go.Figure(data=[go.Pie(values=dt, labels=['Yes','No'])])
        fig.update_layout(
            title_text="ANXIETY")
        
    if(fact3=='PEER_PRESSURE' and graph_type=='Bar Chart'):
        dt = pd.DataFrame((((data_No['PEER_PRESSURE'].value_counts())/len(data_No))*100).round())
        dt.rename(index = {2:"Yes",1:"No"}, inplace=True)
        fig = px.bar(dt)
        fig.update_layout(
            title_text="PEER_PRESSURE")
        
    if(fact3=='PEER_PRESSURE' and graph_type=='Pie Chart'):
        dt=data_No['PEER_PRESSURE'].value_counts()
        fig = go.Figure(data=[go.Pie(values=dt, labels=['Yes','No'])])
        fig.update_layout(
            title_text="PEER_PRESSURE")
        
    if(fact3=='ALLERGY ' and graph_type=='Bar Chart'):
        dt = pd.DataFrame((((data_No['ALLERGY '].value_counts())/len(data_No))*100).round())
        dt.rename(index = {2:"Yes",1:"No"}, inplace=True)
        fig = px.bar(dt)
        fig.update_layout(
            title_text="ALLERGY")
        
    if(fact3=='ALLERGY ' and graph_type=='Pie Chart'):
        dt=data_No['ALLERGY '].value_counts()
        fig = go.Figure(data=[go.Pie(values=dt, labels=['Yes','No'])])
        fig.update_layout(
            title_text="ALLERGY")
        
    fig.update_layout({'plot_bgcolor':colors['background2'],
                'yaxis_title':"Percent",
                'paper_bgcolor': colors['background2'],
                 'font': {'color': colors['text']}
                })
        
    return fig

# %%
if __name__== '__main__':
    app.run_server(port=8090)
# Out:
# Dash is running on http://127.0.0.1:8090/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8090/ (Press CTRL+C to quit)
# 127.0.0.1 - - [09/Mar/2023 09:32:35] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2023 09:32:35] "GET /_dash-component-suites/dash/deps/polyfill@7.v2_8_1m1678334530.12.1.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2023 09:32:35] "GET /_dash-component-suites/dash/deps/react@16.v2_8_1m1678334530.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2023 09:32:35] "GET /_dash-component-suites/dash/deps/react-dom@16.v2_8_1m1678334530.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Mar/2023 09:32:35] "GET /_dash-component-suites/dash/deps/prop-types@15.v2_8_1m1678334530.8.1.min.js HTTP/1.1" 200 -
# ...
